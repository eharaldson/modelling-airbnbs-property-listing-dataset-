# %%
import pandas as pd
import os

df = pd.read_csv('data/tabular_data/clean_listing.csv')
print(df.head())
df.groupby('Category').count()
# Out:
#                                      ID    Category  \
# 0  f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1  1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2  d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3  ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4  cfe479b9-c8f8-44af-9bc6-46ede9f14bb5  Treehouses
#
#                                               Title  \
# 0                 Red Kite Tree Tent - Ynys Affalon
# 1    Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                         Cabane Entre Les Pins🌲🏕️🌲
# 3  Tree Top Cabin with log burner & private hot tub
# 4                       Treehouse near Paris Disney
#
#                                          Description  \
# 0  Escape to one of these two fabulous Tree Tents...
# 1  Come and spend a romantic stay with a couple o...
# 2  Rustic cabin between the pines, 3 meters high ...
# 3  The Tree top cabin is situated in our peaceful...
# 4  Charming cabin nestled in the leaves, real unu...
#
# ...

# %%
166+124+192+165+183
# Out:
# 830

# %%
df.groupby('bedrooms').count()
# Out:
#            ID  Category  Title  Description  Amenities  Location  guests  \
# bedrooms
# 1.0       508       508    508          508        508       508     508
# 2.0       194       194    194          194        194       194     194
# 3.0        76        76     76           76         76        76      76
# 4.0        30        30     30           30         30        30      30
# 5.0        14        14     14           14         14        14      14
# 6.0         5         5      5            5          5         5       5
# 7.0         1         1      1            1          1         1       1
# 8.0         1         1      1            1          1         1       1
# 10.0        1         1      1            1          1         1       1
#
#           beds  bathrooms  Price_Night  Cleanliness_rating  Accuracy_rating  \
# bedrooms
# 1.0        508        508          508                 508              508
# ...

# %%
(508+194)/830
# Out:
# 0.8457831325301205

# %%
508/830
# Out:
# 0.6120481927710844
